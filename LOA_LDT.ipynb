# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
from scipy import stats
from sklearn import linear_model

# %%
df = pd.read_excel("LOA_LDT.xlsx")

# %%
# %matplotlib inline
plt.xlabel('LOA (metres)')
plt.ylabel('LDT (MT)')
plt.scatter(df.LOA, df.LDT, color = 'blue', marker = '*')
plt.plot(df.LOA,reg.predict(df[['LOA']]), color = 'red')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['LOA']], df.LDT)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# -9979.3297909471

# %%
reg.coef_
# Out:
# array([115.3712812])

# %%
slope, intercept, r, p, std_err = stats.linregress(df.LOA,df.LDT)

# %%
print(r)
# Out:
# 0.9072102180230537

# %%
mymodel = numpy.poly1d(numpy.polyfit(df.LOA, df.LDT, 2))
myline = numpy.linspace(start=df['LOA'].min(), stop=df['LOA'].max())
plt.xlabel('LOA (metres)')
plt.ylabel('LDT (MT)')
plt.scatter(df.LOA, df.LDT)
plt.plot(myline, mymodel(myline), color='red')
plt.show()

# %%
from sklearn.metrics import r2_score
mymodel = numpy.poly1d(numpy.polyfit(df.LOA, df.LDT, 2))

print(r2_score(df.LDT, mymodel(df.LOA)))
# Out:
# 0.909298705270526

# %%
mymodel = numpy.poly1d(numpy.polyfit(df.LOA, df.LDT, 3))
myline = numpy.linspace(start=df['LOA'].min(), stop=df['LOA'].max())
plt.xlabel('LOA (metres)')
plt.ylabel('LDT (MT)')
plt.scatter(df.LOA, df.LDT)
plt.plot(myline, mymodel(myline), color='red')
plt.show()

# %%
from sklearn.metrics import r2_score
mymodel = numpy.poly1d(numpy.polyfit(df.LOA, df.LDT, 3))

print(r2_score(df.LDT, mymodel(df.LOA)))
# Out:
# 0.9213276027317335
