# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
from scipy import stats
from sklearn import linear_model

# %%
df = pd.read_excel("GRT_LDT.xlsx")

# %%
# %matplotlib inline
plt.xlabel('GRT (MT)')
plt.ylabel('LDT (MT)')
plt.scatter(df.GRT, df.LDT, color = 'blue', marker = '*')
plt.plot(df.GRT,reg.predict(df[['GRT']]), color = 'red')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['GRT']], df.LDT)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# 2247.5244997297777

# %%
reg.coef_
# Out:
# array([0.25309466])

# %%
slope, intercept, r, p, std_err = stats.linregress(df.GRT,df.LDT)
print(r)
# Out:
# 0.9695461405056356

# %%
from sklearn.metrics import r2_score
mymodel = numpy.poly1d(numpy.polyfit(df.GRT, df.LDT, 2))

print(r2_score(df.LDT, mymodel(df.GRT)))
# Out:
# 0.9424357401957694

# %%
mymodel = numpy.poly1d(numpy.polyfit(df.GRT, df.LDT, 2))
myline = numpy.linspace(start=df['GRT'].min(), stop=df['GRT'].max())
plt.xlabel('GRT (MT)')
plt.ylabel('LDT (MT)')
plt.scatter(df.GRT, df.LDT)
plt.plot(myline, mymodel(myline), color='red')
plt.show()

# %%
mymodel = numpy.poly1d(numpy.polyfit(df.GRT, df.LDT, 3))
myline = numpy.linspace(start=df['GRT'].min(), stop=df['GRT'].max())
plt.xlabel('GRT (MT)')
plt.ylabel('LDT (MT)')
plt.scatter(df.GRT, df.LDT)
plt.plot(myline, mymodel(myline), color='red')
plt.show()

# %%
from sklearn.metrics import r2_score
mymodel = numpy.poly1d(numpy.polyfit(df.GRT, df.LDT, 3))

print(r2_score(df.LDT, mymodel(df.GRT)))
# Out:
# 0.949169880018002
