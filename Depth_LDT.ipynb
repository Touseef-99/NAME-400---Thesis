# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
from scipy import stats
from sklearn import linear_model

# %%
df = pd.read_excel("Depth_LDT.xlsx")

# %%
# %matplotlib inline
plt.xlabel('Depth (metres)')
plt.ylabel('LDT (MT)')
plt.scatter(df.Depth, df.LDT, color = 'blue', marker = '*')
plt.plot(df.Depth,reg.predict(df[['Depth']]), color = 'red')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['Depth']], df.LDT)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# -8018.193045163032

# %%
reg.coef_
# Out:
# array([1282.55367105])

# %%
slope, intercept, r, p, std_err = stats.linregress(df.Depth,df.LDT)
print(r)
# Out:
# 0.8415114249244414

# %%
from sklearn.metrics import r2_score
mymodel = numpy.poly1d(numpy.polyfit(df.Depth, df.LDT, 2))

print(r2_score(df.LDT, mymodel(df.Depth)))
# Out:
# 0.7567396185970371

# %%
mymodel = numpy.poly1d(numpy.polyfit(df.Depth, df.LDT, 2))
myline = numpy.linspace(start=df['Depth'].min(), stop=df['Depth'].max())
plt.xlabel('Depth (metres)')
plt.ylabel('LDT (MT)')
plt.scatter(df.Depth, df.LDT)
plt.plot(myline, mymodel(myline), color='red')
plt.show()

# %%
mymodel = numpy.poly1d(numpy.polyfit(df.Depth, df.LDT, 3))
myline = numpy.linspace(start=df['Depth'].min(), stop=df['Depth'].max())
plt.xlabel('Depth (metres)')
plt.ylabel('LDT (MT)')
plt.scatter(df.Depth, df.LDT)
plt.plot(myline, mymodel(myline), color='red')
plt.show()

# %%
from sklearn.metrics import r2_score
mymodel = numpy.poly1d(numpy.polyfit(df.Depth, df.LDT, 3))

print(r2_score(df.LDT, mymodel(df.Depth)))
# Out:
# 0.7569426208095742
