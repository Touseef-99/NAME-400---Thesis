# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import pearsonr

# %%
df = pd.read_excel('Correlation.xlsx')

# %%
df.head()
# Out:
#    Year of Build  LOA (m)  Breadth (m)  Depth (m)  LDT (MT)  GRT (MT)  \
# 0         2004.0    89.04         13.8        7.4   1313.10    2785.0
# 1         1995.0   180.60         31.0       16.5   8118.00   26071.0
# 2         1996.0   163.89         26.5       14.2   8170.10   17287.0
# 3         1995.0   217.34         32.2       18.8  10339.00   38205.0
# 4         1997.0   159.62         27.2       13.8   6821.48   16915.0
#
#        NRT  BHP (kW)
# 0   1636.0    1470.0
# 1  15556.0    7582.0
# 2   8849.0   16200.0
# 3  24113.0    6750.0
# 4   7595.0   11950.0

# %%
corr_matrix = df.corr().round(3)

# %%
corr_matrix
# Out:
#                Year of Build  LOA (m)  Breadth (m)  Depth (m)  LDT (MT)  \
# Year of Build          1.000    0.334        0.191      0.348     0.294
# LOA (m)                0.334    1.000        0.620      0.905     0.907
# Breadth (m)            0.191    0.620        1.000      0.593     0.619
# Depth (m)              0.348    0.905        0.593      1.000     0.842
# LDT (MT)               0.294    0.907        0.619      0.842     1.000
# GRT (MT)               0.290    0.885        0.622      0.835     0.970
# NRT                    0.300    0.857        0.577      0.802     0.907
# BHP (kW)               0.243    0.576        0.313      0.495     0.568
#
#                GRT (MT)    NRT  BHP (kW)
# Year of Build     0.290  0.300     0.243
# LOA (m)           0.885  0.857     0.576
# Breadth (m)       0.622  0.577     0.313
# Depth (m)         0.835  0.802     0.495
# LDT (MT)          0.970  0.907     0.568
# GRT (MT)          1.000  0.952     0.496
# NRT               0.952  1.000     0.459
# BHP (kW)          0.496  0.459     1.000

# %%
corr_matrix["LDT (MT)"]
# Out:
# Year of Build    0.294
# LOA (m)          0.907
# Breadth (m)      0.619
# Depth (m)        0.842
# LDT (MT)         1.000
# GRT (MT)         0.970
# NRT              0.907
# BHP (kW)         0.568
# Name: LDT (MT), dtype: float64

# %%
df.describe().round(3)
# Out:
#        Year of Build   LOA (m)  Breadth (m)  Depth (m)   LDT (MT)    GRT (MT)  \
# count       1429.000  1430.000     1428.000   1430.000   1428.000    1430.000
# mean        1989.693   178.114       29.426     14.492  10570.028   32871.741
# std            8.132    69.611       17.610      5.808   8858.733   33913.296
# min         1883.000    28.590        6.800      2.900    280.420     174.000
# 25%         1984.000   121.220       20.000      9.948   3715.975    6950.500
# 50%         1990.000   176.520       29.000     14.600   8177.705   23403.000
# 75%         1996.000   226.258       32.250     18.390  15394.750   41720.000
# max         2015.000   340.000      500.000     31.820  48100.000  164371.000
#
#               NRT    BHP (kW)
# count    1411.000    1246.000
# mean    18002.048   10501.998
# std     19549.745   11022.127
# min        52.000      73.500
# 25%      3562.000    4560.000
# 50%     12298.000    8310.000
# 75%     24359.500   12798.500
# max    110069.000  169000.000

# %%
plt.figure(figsize=(10,8))
plot = sns.heatmap(df.corr().round(3), annot = True)
plot.set_title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')
